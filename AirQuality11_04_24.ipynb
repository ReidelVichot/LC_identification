# %% [markdown]
# <a href="https://colab.research.google.com/github/ReidelVichot/LC_identification/blob/main/AirQuality11_04_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# -- Setting environment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# -- Import each of the csv
dir = "/content/drive/MyDrive/Disertation/EPA_data/"
year = 2020
fname = f"annual_aqi_by_county_{year}/annual_aqi_by_county_{year}.csv"

aqi_20 = pd.read_csv(dir + fname)

# %%
# -- Import daily AQI for a year


# -- Group by State, County .. preserve standard deviation mean, max and min

# %%
def get_AQI(year):
  dir = "/content/drive/MyDrive/Disertation/EPA_data/AQI"
  fname = f"/daily_aqi_by_county_{year}.csv"
  return pd.read_csv(dir + fname)

def gen_GEOID(df):
  # generate GEOID
  df["GEOID"] = df["State Code"].astype(str).str.zfill(2) + df["County Code"].astype(str).str.zfill(3)
  # get year
  df["year"] = df["Date"].str[:4]
  # eliminate non-relevant data
  df = df[["GEOID", "AQI", "year"]]
  df = df.groupby(["GEOID", "year"]).agg(["mean", "std", "max", "min"])
  # combining columns
  df.columns = ["_".join(col) for col in df.columns]
  df = df.reset_index()
  return df
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2020-01-01   56
# 1         Alabama     Baldwin           1            3  2020-01-04   18
# 2         Alabama     Baldwin           1            3  2020-01-07   18
# 3         Alabama     Baldwin           1            3  2020-01-10   51
# 4         Alabama     Baldwin           1            3  2020-01-13   38
# ...           ...         ...         ...          ...         ...  ...
# 325131    Wyoming      Weston          56           45  2020-12-27   32
# 325132    Wyoming      Weston          56           45  2020-12-28   30
# 325133    Wyoming      Weston          56           45  2020-12-29   33
# 325134    Wyoming      Weston          56           45  2020-12-30   33
# 325135    Wyoming      Weston          56           45  2020-12-31   34
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
# Out:
#       GEOID  year    AQI_mean    AQI_std  AQI_max  AQI_min
# 0     01003  2020   37.539033  12.050708       74       13
# 1     01027  2020   35.561905  14.751091       88       11
# 2     01049  2020   37.101648   9.835176       91       13
# 3     01051  2020   30.360406   8.255923       47       15
# 4     01055  2020   36.974638  11.828290       93       12
# ...     ...   ...         ...        ...      ...      ...
# 1001  78010  2020   31.593220  17.010259       84        6
# 1002  78020  2020   27.297297  17.203908       84        6
# 1003  78030  2020   35.506667  16.134044       75       17
# 1004  80002  2020  114.358696  33.959116      185       55
# 1005  80026  2020   43.239726  14.690511      101        5
#
# [1006 rows x 6 columns]

# %%
df.columns[3:]
# Out:
# Index(['County Code', 'Date', 'AQI', 'Category', 'Defining Parameter',
#        'Defining Site', 'Number of Sites Reporting', 'GEOID', 'year'],
#       dtype='object')
